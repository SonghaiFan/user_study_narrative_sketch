# %%
import pandas as pd
import json
import numpy as np

# Load the CSV file
csv_file_path = './data/prolific_export_65566952c6b6b608da9084b0.csv'
csv_data = pd.read_csv(csv_file_path)

# Load the JSON file
json_file_path = './data/user-study-narrative-sketch-default-rtdb-export.json'
with open(json_file_path, 'r') as file:
    actions = json.load(file)

# Extracting and renaming demographic information from the CSV data
# demographics = csv_data[['Participant id', 'Age', 'Sex', 'Ethnicity simplified', 'Country of birth', 'Country of residence', 'Nationality', 'Language', 'Student status', 'Employment status']]
demographics = csv_data[['Participant id', 'Age', 'Sex']]
demographics = demographics.rename(columns={
    'Participant id': 'Participant ID'
})

# %%
# Flatten the JSON data 
flattened_data = []
for participant_id, data in actions.items():


    # Route Path Navigation Data
    for route_data in data.get('routePathNavigation', {}).values():
        combined_data = {**route_data, 'navType': 'routePathNav'}
        flattened_data.append(combined_data)

    # User Selections Data
    for selection_data in data.get('userSelections', {}).values():
        combined_data = {**selection_data, 'navType': 'userSelectionNav'}
        flattened_data.append(combined_data)

actions_data_df = pd.DataFrame(flattened_data)

# Convert the currentIndex if exist to an integer
actions_data_df['currentIndex'] = actions_data_df['currentIndex'].astype('Int64').astype('str')


# Updating the Route Path for 'training' and 'task' modes using vectorized operations
condition = actions_data_df['mode'].isin(['training', 'task'])
actions_data_df['routePath'] = np.where(
    condition, 
    "/" + actions_data_df['mode'] + 
    "/" + actions_data_df['currentIndex'] +
    actions_data_df['routePath']
)


actions_data_df[actions_data_df['mode']=='training'].head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/roperator.py:11, in radd(left, right)
#      10 def radd(left, right):
# ---> 11     return right + left
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=21'>22</a> # Updating the Route Path for 'training' and 'task' modes using vectorized operations
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a> condition = actions_data_df['mode'].isin(['training', 'task'])
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=23'>24</a> actions_data_df['routePath'] = np.where(
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a>     condition,
# ---> <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=25'>26</a>     "/" + actions_data_df['mode'] +
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=26'>27</a>     "/" + actions_data_df['currentIndex'] +
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=27'>28</a>     actions_data_df['routePath']
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=28'>29</a> )
#      <a href='vscode-notebook-cell:/Users/songhaifan/Documents/GitHub/user_study_narrative_sketch/.data_process/data_tidyer.ipynb#X24sZmlsZQ%3D%3D?line=31'>32</a> actions_data_df[actions_data_df['mode']=='training'].head(10)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/series.py:5815, in Series._arith_method(self, other, op)
#    5813 def _arith_method(self, other, op):
#    5814     self, other = self._align_for_op(other)
# -> 5815     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:275, in arithmetic_op(left, right, op)
#     262 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     263 #  have already been called on `left` and `right`,
#     264 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     265 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     266 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     268 if (
#     269     should_extension_dispatch(left, right)
#     270     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     273     # Timedelta/Timestamp and other custom scalars are included in the check
#     274     # because numexpr will fail on it, see GH#31457
# --> 275     res_values = op(left, right)
#     276 else:
#     277     # TODO we should handle EAs consistently and move this check before the if/else
#     278     # (https://github.com/pandas-dev/pandas/issues/41165)
#     279     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     280     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/arrays/masked.py:590, in BaseMaskedArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     587         return NotImplemented
#     589 # for binary ops, use our custom dunder methods
# --> 590 result = arraylike.maybe_dispatch_ufunc_to_dunder_op(
#     591     self, ufunc, method, *inputs, **kwargs
#     592 )
#     593 if result is not NotImplemented:
#     594     return result
#
# File ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/arraylike.py:190, in OpsMixin.__radd__(self, other)
#     188 @unpack_zerodim_and_defer("__radd__")
#     189 def __radd__(self, other):
# --> 190     return self._arith_method(other, roperator.radd)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/arrays/masked.py:760, in BaseMaskedArray._arith_method(self, other, op)
#     757         pd_op = op
#     759     with np.errstate(all="ignore"):
# --> 760         result = pd_op(self._data, other)
#     762 if op_name == "pow":
#     763     # 1 ** x is 1.
#     764     mask = np.where((self._data == 1) & ~self._mask, False, mask)
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# File /usr/local/anaconda3/envs/nlp/lib/python3.11/site-packages/pandas/core/roperator.py:11, in radd(left, right)
#      10 def radd(left, right):
# ---> 11     return right + left
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Flatten the JSON data and combine with demographic data
flattened_data = []
for participant_id, data in actions.items():
    # Ensure participant is in demographics
    if participant_id not in demographics['Participant ID'].values:
        continue

    demo_info = demographics[demographics['Participant ID'] == participant_id].iloc[0].to_dict()

    # Route Path Navigation Data
    for route_data in data.get('routePathNavigation', {}).values():
        combined_data = {**demo_info, **route_data, 'navType': 'routePathNav'}
        flattened_data.append(combined_data)

    # User Selections Data
    for selection_data in data.get('userSelections', {}).values():
        combined_data = {**demo_info, **selection_data, 'navType': 'userSelectionNav'}
        flattened_data.append(combined_data)

# Convert to DataFrame
combined_data_df = pd.DataFrame(flattened_data)
# exclude "reason" column
combined_data_df
# Out:
#                Participant ID Age     Sex  routePath      timestamp  \
# 0    5d05c531dc2d54001838ce76  44  Female     /intro  1700167160650
# 1    5d05c531dc2d54001838ce76  44  Female    /motifs  1700167258392
# 2    5d05c531dc2d54001838ce76  44  Female     /about  1700167298863
# 3    5d05c531dc2d54001838ce76  44  Female  /training  1700167328371
# 4    5d05c531dc2d54001838ce76  44  Female      /task  1700167709762
# ..                        ...  ..     ...        ...            ...
# 116  603b750eab9d377aeac41724  25  Female        NaN  1700167732736
# 117  603b750eab9d377aeac41724  25  Female        NaN  1700167793622
# 118  603b750eab9d377aeac41724  25  Female        NaN  1700167840064
# 119  603b750eab9d377aeac41724  25  Female        NaN  1700167888720
# 120  603b750eab9d377aeac41724  25  Female        NaN  1700167928701
#
#               navType  currentIndex decision  mode  \
# 0        routePathNav           NaN      NaN   NaN
# 1        routePathNav           NaN      NaN   NaN
# 2        routePathNav           NaN      NaN   NaN
# 3        routePathNav           NaN      NaN   NaN
# 4        routePathNav           NaN      NaN   NaN
# ..                ...           ...      ...   ...
# 116  userSelectionNav           5.0  confirm  task
# 117  userSelectionNav           6.0  confirm  task
# 118  userSelectionNav           7.0  confirm  task
# 119  userSelectionNav           8.0  confirm  task
# 120  userSelectionNav           9.0  confirm  task
#
#                                                 reason rightSelection  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 116           Each passage leads on from one another.       ShortFork
# 117  last passage is a bit random and disrupts the ...         Ladder
# 118  The story is relevant and follows on from each...       LongFork
# 119  Three separate passages. However, the first an...     WideBranch
# 120     First and last passage seem to link together.     SharpBranch
#
#      selection                                         story
# 0          NaN                                           NaN
# 1          NaN                                           NaN
# 2          NaN                                           NaN
# 3          NaN                                           NaN
# 4          NaN                                           NaN
# ..         ...                                           ...
# 116     Ladder    story_Muddle_Puddle_ShortFork_seed158.json
# 117   LongFork       story_Muddle_Puddle_Ladder_seed241.json
# 118     Ladder     story_Muddle_Puddle_LongFork_seed288.json
# 119  WideMerge   story_Muddle_Puddle_WideBranch_seed496.json
# 120  WideMerge  story_Muddle_Puddle_SharpBranch_seed178.json
#
# [121 rows x 13 columns]

# %%
# Ensure 'Timestamp (Decision)' and 'Timestamp (Route Path)' columns are correctly formatted and exist
combined_data_df['Timestamp (Decision)'] = combined_data_df.get('timestamp', pd.NaT)
combined_data_df['Timestamp (Route Path)'] = combined_data_df.get('timestamp', pd.NaT)

# group by participant id and sort by timestamp, 
# and get the difference between the current and next timestamp, /end has no next difference duration



# Merging Timestamps using combine_first
combined_data_df['Timestamp'] = combined_data_df['Timestamp (Decision)'].combine_first(combined_data_df['Timestamp (Route Path)'])

# Convert the currentIndex if exist to an integer
combined_data_df['currentIndex'] = combined_data_df['currentIndex'].astype('Int64')


# Updating the Route Path for 'training' and 'task' modes using vectorized operations
condition = combined_data_df['mode'].isin(['training', 'task'])
combined_data_df['Route Path'] = np.where(
    condition, 
    "/" + combined_data_df['mode'] + "/" + combined_data_df['currentIndex'].astype(str),
    combined_data_df['routePath']
)

# Dropping old timestamp columns and other unnecessary columns
combined_data_df = combined_data_df.drop(columns=['Timestamp (Route Path)', 'Timestamp (Decision)', 'timestamp', 'mode', 'currentIndex', 'routePath'])

# Show the updated DataFrame structure
combined_data_df.head(10)

# %%
combined_data_df.to_csv('output.csv', index=False)

# %%
# Group the data by participant ID
grouped_data = combined_data_df.groupby('Participant ID')

# Sort the data by timestamp and route path within each group
sorted_data = grouped_data.apply(lambda x: x.sort_values(['Timestamp']))

# Reset the index
sorted_data.reset_index(drop=True, inplace=True)



# Show the updated DataFrame structure
sorted_data
# Out:
#                Participant ID Age     Sex decision  \
# 0    5d05c531dc2d54001838ce76  44  Female      NaN
# 1    5d05c531dc2d54001838ce76  44  Female      NaN
# 2    5d05c531dc2d54001838ce76  44  Female      NaN
# 3    5d05c531dc2d54001838ce76  44  Female      NaN
# 4    5d05c531dc2d54001838ce76  44  Female   cancel
# ..                        ...  ..     ...      ...
# 116  603b750eab9d377aeac41724  25  Female  confirm
# 117  603b750eab9d377aeac41724  25  Female  confirm
# 118  603b750eab9d377aeac41724  25  Female  confirm
# 119  603b750eab9d377aeac41724  25  Female  confirm
# 120  603b750eab9d377aeac41724  25  Female      NaN
#
#                                                 reason rightSelection  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                           ShortFork
# ..                                                 ...            ...
# 116  last passage is a bit random and disrupts the ...         Ladder
# 117  The story is relevant and follows on from each...       LongFork
# 118  Three separate passages. However, the first an...     WideBranch
# 119     First and last passage seem to link together.     SharpBranch
# 120                                                NaN            NaN
#
#      selection                                         story      Timestamp  \
# 0          NaN                                           NaN  1700167160650
# 1          NaN                                           NaN  1700167258392
# 2          NaN                                           NaN  1700167298863
# 3          NaN                                           NaN  1700167328371
# 4       Linear    story_Muddle_Puddle_ShortFork_seed942.json  1700167401299
# ..         ...                                           ...            ...
# 116   LongFork       story_Muddle_Puddle_Ladder_seed241.json  1700167793622
# 117     Ladder     story_Muddle_Puddle_LongFork_seed288.json  1700167840064
# 118  WideMerge   story_Muddle_Puddle_WideBranch_seed496.json  1700167888720
# 119  WideMerge  story_Muddle_Puddle_SharpBranch_seed178.json  1700167928701
# 120        NaN                                           NaN  1700167928755
#
#       Route Path
# 0         /intro
# 1        /motifs
# 2         /about
# 3      /training
# 4    /training/0
# ..           ...
# 116      /task/6
# 117      /task/7
# 118      /task/8
# 119      /task/9
# 120         /end
#
# [121 rows x 10 columns]
